# %%
from tensorflow.python.keras.datasets import boston_housing
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense

# %%
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %%
# Среднее значение
mean = x_train.mean(axis=0)
# Стандартное отклонение
std = x_train.std(axis=0)
x_train -= mean
x_train /= std
x_test -= mean
x_test /= std

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(1))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0714 03:48:21.393825 139693931325312 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.fit(x_train, y_train, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
# 404/404 - 2s - loss: 305.8797 - mean_absolute_error: 14.6665
# Epoch 2/50
# 404/404 - 1s - loss: 45.1189 - mean_absolute_error: 4.4893
# Epoch 3/50
# 404/404 - 1s - loss: 26.9319 - mean_absolute_error: 3.5066
# Epoch 4/50
# 404/404 - 1s - loss: 22.1146 - mean_absolute_error: 3.2675
# Epoch 5/50
# 404/404 - 1s - loss: 18.6217 - mean_absolute_error: 3.0589
# Epoch 6/50
# 404/404 - 1s - loss: 15.9532 - mean_absolute_error: 2.8355
# Epoch 7/50
# 404/404 - 1s - loss: 14.0411 - mean_absolute_error: 2.6786
# Epoch 8/50
# 404/404 - 1s - loss: 12.8837 - mean_absolute_error: 2.5525
# Epoch 9/50
# 404/404 - 1s - loss: 11.5047 - mean_absolute_error: 2.4028
# Epoch 10/50
# 404/404 - 1s - loss: 10.7796 - mean_absolute_error: 2.3648
# Epoch 11/50
# 404/404 - 1s - loss: 10.2002 - mean_absolute_error: 2.2577
# Epoch 12/50
# 404/404 - 1s - loss: 9.8406 - mean_absolute_error: 2.2040
# Epoch 13/50
# 404/404 - 1s - loss: 9.5378 - mean_absolute_error: 2.1781
# Epoch 14/50
# 404/404 - 1s - loss: 9.3591 - mean_absolute_error: 2.2218
# Epoch 15/50
# 404/404 - 1s - loss: 8.6832 - mean_absolute_error: 2.0654
# Epoch 16/50
# 404/404 - 1s - loss: 8.8632 - mean_absolute_error: 2.1347
# Epoch 17/50
# 404/404 - 1s - loss: 8.4669 - mean_absolute_error: 2.0362
# Epoch 18/50
# 404/404 - 1s - loss: 8.3194 - mean_absolute_error: 2.0322
# Epoch 19/50
# 404/404 - 1s - loss: 8.0669 - mean_absolute_error: 1.9881
# Epoch 20/50
# 404/404 - 1s - loss: 8.0677 - mean_absolute_error: 1.9832
# Epoch 21/50
# 404/404 - 1s - loss: 8.0222 - mean_absolute_error: 2.0019
# Epoch 22/50
# 404/404 - 1s - loss: 7.8231 - mean_absolute_error: 1.9674
# Epoch 23/50
# 404/404 - 1s - loss: 7.6784 - mean_absolute_error: 1.9922
# Epoch 24/50
# 404/404 - 1s - loss: 7.3232 - mean_absolute_error: 1.8827
# Epoch 25/50
# 404/404 - 1s - loss: 7.5178 - mean_absolute_error: 1.9540
# Epoch 26/50
# 404/404 - 1s - loss: 7.2106 - mean_absolute_error: 1.8767
# Epoch 27/50
# 404/404 - 1s - loss: 7.0854 - mean_absolute_error: 1.9186
# Epoch 28/50
# 404/404 - 1s - loss: 7.2783 - mean_absolute_error: 1.8838
# Epoch 29/50
# 404/404 - 1s - loss: 6.8687 - mean_absolute_error: 1.8693
# Epoch 30/50
# 404/404 - 1s - loss: 6.7857 - mean_absolute_error: 1.8074
# Epoch 31/50
# 404/404 - 1s - loss: 6.9722 - mean_absolute_error: 1.8700
# Epoch 32/50
# 404/404 - 1s - loss: 6.6960 - mean_absolute_error: 1.8101
# Epoch 33/50
# 404/404 - 1s - loss: 6.6042 - mean_absolute_error: 1.8236
# Epoch 34/50
# 404/404 - 1s - loss: 6.5589 - mean_absolute_error: 1.8099
# Epoch 35/50
# 404/404 - 1s - loss: 6.4674 - mean_absolute_error: 1.8085
# Epoch 36/50
# 404/404 - 1s - loss: 6.8376 - mean_absolute_error: 1.8543
# Epoch 37/50
# 404/404 - 1s - loss: 6.0551 - mean_absolute_error: 1.7464
# Epoch 38/50
# 404/404 - 1s - loss: 6.1798 - mean_absolute_error: 1.7862
# Epoch 39/50
# 404/404 - 1s - loss: 6.2988 - mean_absolute_error: 1.7775
# Epoch 40/50
# 404/404 - 1s - loss: 6.1171 - mean_absolute_error: 1.7656
# Epoch 41/50
# 404/404 - 1s - loss: 6.2836 - mean_absolute_error: 1.7539
# Epoch 42/50
# 404/404 - 1s - loss: 5.9803 - mean_absolute_error: 1.7566
# Epoch 43/50
# 404/404 - 1s - loss: 6.1588 - mean_absolute_error: 1.7652
# Epoch 44/50
# 404/404 - 1s - loss: 6.2347 - mean_absolute_error: 1.7554
# Epoch 45/50
# 404/404 - 1s - loss: 5.9825 - mean_absolute_error: 1.7209
# Epoch 46/50
# 404/404 - 1s - loss: 6.0900 - mean_absolute_error: 1.7477
# Epoch 47/50
# 404/404 - 1s - loss: 6.0824 - mean_absolute_error: 1.7836
# Epoch 48/50
# 404/404 - 1s - loss: 5.8810 - mean_absolute_error: 1.6875
# Epoch 49/50
# 404/404 - 1s - loss: 5.8928 - mean_absolute_error: 1.7186
# Epoch 50/50
# 404/404 - 1s - loss: 5.7924 - mean_absolute_error: 1.6769

# %%
pred = model.predict(x_test)

# %%
test_index=7
print("Предсказанная стоимость:", pred[test_index][0], ", правильная стоимость:", y_test[test_index])
# Out:
# Предсказанная стоимость: 22.605385 , правильная стоимость: 22.9
